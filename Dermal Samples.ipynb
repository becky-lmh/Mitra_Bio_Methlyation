# %%
# Completing PCA Analysis on 40 samples from Vandiver's research

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Load the beta values for Old Sun Exposed
Oexp_data_path1 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255799-4943.txt'
OE1 = np.loadtxt(Oexp_data_path1, delimiter='	', skiprows=3, usecols=1, dtype=str)

Oexp_data_path2 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255800-4944.txt'
OE2 = np.loadtxt(Oexp_data_path2, delimiter='	', skiprows=3, usecols=1, dtype=str)

Oexp_data_path3 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255801-4945.txt'
OE3 = np.loadtxt(Oexp_data_path3, delimiter='	', skiprows=3, usecols=1, dtype=str)

Oexp_data_path4 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255802-4946.txt'
OE4 = np.loadtxt(Oexp_data_path4, delimiter='	', skiprows=3, usecols=1, dtype=str)

Oexp_data_path5 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255803-4947.txt'
OE5 = np.loadtxt(Oexp_data_path5, delimiter='	', skiprows=3, usecols=1, dtype=str)

Oexp_data_path6 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255804-4948.txt'
OE6 = np.loadtxt(Oexp_data_path6, delimiter='	', skiprows=3, usecols=1, dtype=str)

Oexp_data_path7 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255805-4949.txt'
OE7 = np.loadtxt(Oexp_data_path7, delimiter='	', skiprows=3, usecols=1, dtype=str)

Oexp_data_path8 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255806-4950.txt'
OE8 = np.loadtxt(Oexp_data_path8, delimiter='	', skiprows=3, usecols=1, dtype=str)

Oexp_data_path9 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255807-4951.txt'
OE9 = np.loadtxt(Oexp_data_path9, delimiter='	', skiprows=3, usecols=1, dtype=str)

Oexp_data_path10 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255808-4952.txt'
OE10 = np.loadtxt(Oexp_data_path10, delimiter='	', skiprows=3, usecols=1, dtype=str)

# %%
# Load the beta values Old Sun Protected
Opro_data_path1 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255789-4933.txt'
OP1 = np.loadtxt(Opro_data_path1, delimiter='	', skiprows=3, usecols=1, dtype=str)

Opro_data_path2 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255790-4934.txt'
OP2 = np.loadtxt(Opro_data_path2, delimiter='	', skiprows=3, usecols=1, dtype=str)

Opro_data_path3 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255791-4935.txt'
OP3 = np.loadtxt(Opro_data_path3, delimiter='	', skiprows=3, usecols=1, dtype=str)

Opro_data_path4 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255792-4936.txt'
OP4 = np.loadtxt(Opro_data_path4, delimiter='	', skiprows=3, usecols=1, dtype=str)

Opro_data_path5 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255793-4937.txt'
OP5 = np.loadtxt(Opro_data_path5, delimiter='	', skiprows=3, usecols=1, dtype=str)

Opro_data_path6 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255794-4938.txt'
OP6 = np.loadtxt(Opro_data_path6, delimiter='	', skiprows=3, usecols=1, dtype=str)

Opro_data_path7 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255795-4939.txt'
OP7 = np.loadtxt(Opro_data_path7, delimiter='	', skiprows=3, usecols=1, dtype=str)

Opro_data_path8 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255796-4940.txt'
OP8 = np.loadtxt(Opro_data_path8, delimiter='	', skiprows=3, usecols=1, dtype=str)

Opro_data_path9 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255797-4941.txt'
OP9 = np.loadtxt(Opro_data_path9, delimiter='	', skiprows=3, usecols=1, dtype=str)

Opro_data_path10 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255798-4942.txt'
OP10 = np.loadtxt(Opro_data_path10, delimiter='	', skiprows=3, usecols=1, dtype=str)

# %%
# Load the beta values for Young Sun Exposed
Yexp_data_path1 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255779-4923.txt'
YE1 = np.loadtxt(Yexp_data_path1, delimiter='	', skiprows=3, usecols=1, dtype=str)

Yexp_data_path2 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255780-4924.txt'
YE2 = np.loadtxt(Yexp_data_path2, delimiter='	', skiprows=3, usecols=1, dtype=str)

Yexp_data_path3 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255781-4925.txt'
YE3 = np.loadtxt(Yexp_data_path3, delimiter='	', skiprows=3, usecols=1, dtype=str)

Yexp_data_path4 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255782-4926.txt'
YE4 = np.loadtxt(Yexp_data_path4, delimiter='	', skiprows=3, usecols=1, dtype=str)

Yexp_data_path5 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255783-4927.txt'
YE5 = np.loadtxt(Yexp_data_path5, delimiter='	', skiprows=3, usecols=1, dtype=str)

Yexp_data_path6 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255784-4928.txt'
YE6 = np.loadtxt(Yexp_data_path6, delimiter='	', skiprows=3, usecols=1, dtype=str)

Yexp_data_path7 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255785-4929.txt'
YE7 = np.loadtxt(Yexp_data_path7, delimiter='	', skiprows=3, usecols=1, dtype=str)

Yexp_data_path8 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255786-4930.txt'
YE8 = np.loadtxt(Yexp_data_path8, delimiter='	', skiprows=3, usecols=1, dtype=str)

Yexp_data_path9 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255787-4931.txt'
YE9 = np.loadtxt(Yexp_data_path9, delimiter='	', skiprows=3, usecols=1, dtype=str)

Yexp_data_path10 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255788-4932.txt'
YE10 = np.loadtxt(Yexp_data_path10, delimiter='	', skiprows=3, usecols=1, dtype=str)

# %%
# Load the beta values Young Sun Protected
Ypro_data_path1 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255769-4913.txt'
YP1 = np.loadtxt(Ypro_data_path1, delimiter='	', skiprows=3, usecols=1, dtype=str)

Ypro_data_path2 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255770-4914.txt'
YP2 = np.loadtxt(Ypro_data_path2, delimiter='	', skiprows=3, usecols=1, dtype=str)

Ypro_data_path3 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255771-4915.txt'
YP3 = np.loadtxt(Ypro_data_path3, delimiter='	', skiprows=3, usecols=1, dtype=str)

Ypro_data_path4 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255772-4916.txt'
YP4 = np.loadtxt(Ypro_data_path4, delimiter='	', skiprows=3, usecols=1, dtype=str)

Ypro_data_path5 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255773-4917.txt'
YP5 = np.loadtxt(Ypro_data_path5, delimiter='	', skiprows=3, usecols=1, dtype=str)

Ypro_data_path6 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255774-4918.txt'
YP6 = np.loadtxt(Ypro_data_path6, delimiter='	', skiprows=3, usecols=1, dtype=str)

Ypro_data_path7 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255775-4919.txt'
YP7 = np.loadtxt(Ypro_data_path7, delimiter='	', skiprows=3, usecols=1, dtype=str)

Ypro_data_path8 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255776-4920.txt'
YP8 = np.loadtxt(Ypro_data_path8, delimiter='	', skiprows=3, usecols=1, dtype=str)

Ypro_data_path9 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255777-4921.txt'
YP9 = np.loadtxt(Ypro_data_path9, delimiter='	', skiprows=3, usecols=1, dtype=str)

Ypro_data_path10 = 'C:/Users/black/OneDrive/Documents/Mitra/Mitra_Bio_Methlyation/data/GSM1255778-4922.txt'
YP10 = np.loadtxt(Ypro_data_path10, delimiter='	', skiprows=3, usecols=1, dtype=str)

# %%
# Load the list of genes
gene_list = np.loadtxt(Oexp_data_path1, delimiter='	', skiprows=3, usecols=0, dtype=str)

# %%
# Save data in dataframe
list_tuples=list(zip(OE1,OE2,OE3,OE4,OE5,OE6,OE7,OE8,OE9,OE10,OP1,OP2,OP3,
                    OP4,OP5,OP6,OP7,OP8,OP9,OP10,YE1,YE2,YE3,YE4,YE5,YE6,
                     YE7,YE8,YE9,YE10,YP1,YP2,YP3,YP4,YP5,YP6,YP7,YP8,
                     YP9,YP10))

df = pd.DataFrame(list_tuples, index=gene_list)
df.head()
# Out:
#                             0                   1                   2   \
# cg13869341   0.815654046106181   0.878312199387844   0.841408059286707
# cg14008030   0.599071932546275   0.627416730516057   0.672498703570484
# cg12045430  0.0631819640564827  0.0756385068762279  0.0487450659119684
# cg20826792   0.175329351463549     0.2478088357219   0.189405188226046
# cg00381604   0.027052293309962  0.0285204175059513  0.0165676211057086
#
#                             3                   4                   5   \
# cg13869341   0.793271882139762    0.80330808617069   0.828415161536505
# cg14008030   0.700175118648045   0.694864813477911   0.653626948958294
# cg12045430  0.0762506070908208  0.0795940369530466   0.091763776417144
# cg20826792   0.183444615648006   0.201201823456278   0.178195991968188
# cg00381604  0.0509181969949917  0.0377581452928929  0.0709846627515822
#
#                             6                   7                   8   \
# cg13869341   0.843790992566681   0.864457903430445   0.811932437341082
# cg14008030   0.636000181559468    0.65880732174187   0.689673609337701
# cg12045430  0.0779994458298698  0.0783524310932177  0.0667928706647141
# cg20826792   0.170296226159881   0.217643599294256   0.218289944273476
# cg00381604   0.052509746588694  0.0684973209936678  0.0392294789243006
#
#                             9   ...                  30                  31  \
# cg13869341   0.857823986557446  ...   0.817098168530814    0.87705680705191
# cg14008030   0.654903381496405  ...   0.633201196646628   0.638148232046025
# cg12045430  0.0417823174567929  ...  0.0284990500316656  0.0469373468673434
# cg20826792   0.131421913068041  ...  0.0747000387046833    0.19501258653241
# cg00381604   0.035146173688736  ...   0.014765317669882  0.0325028251627832
#
#                             32                  33                  34  \
# cg13869341   0.861441719269503   0.825483277078858   0.857607719928187
# cg14008030   0.653817724154123   0.602222432757471   0.675901385390146
# cg12045430  0.0622690020890246   0.052456319047246  0.0794353232730008
# cg20826792    0.15366839976892   0.227440044617959   0.193228773270538
# cg00381604  0.0511288531697774  0.0276315044448219  0.0468670725520041
#
#                             35                  36                  37  \
# cg13869341   0.828168646390811   0.831367750374481   0.848129508887622
# cg14008030   0.617495204086508   0.549909603495123   0.571098106132566
# cg12045430  0.0491533990396765   0.027863203527363  0.0789716748768473
# cg20826792   0.213779888361243   0.134950779009379   0.208132792663054
# cg00381604      0.018798828125  0.0234894221500685  0.0431569446011508
#
#                             38                  39
# cg13869341   0.813139299303256    0.92804893589907
# cg14008030    0.63927075008704   0.608448560295938
# cg12045430   0.081285146879547   0.023036223036223
# cg20826792   0.232822284603757   0.139328774518625
# cg00381604  0.0741965973534972  0.0294745581781521
#
# [5 rows x 40 columns]

# %%
# Save data in dataframe
#list_tuples=list(zip(OE1,OE2))
#df = pd.DataFrame(list_tuples, index=gene_list)
#df.head()

# %%
# Create sample headings
OE = ["OE"]*10
OP = ["OP"]*10
YE = ["YE"]*10
YP = ["YP"]*10
sample_list = OE+OP+YE+YP

# %%
# Clean up the empty cells
df1 = df.replace(r'^\s*$', np.nan, regex=True)
df2 = df1.astype(float)
#print(df2.dtypes)

# %%
# Create boxplot
df_box=df2
df_box.columns = sample_list
#df_box.columns = ["a","b"]
fig1, ax1 = plt.subplots(figsize=(12,7))
ax1.set_title("Methylation Values for Dermal Samples")
boxplot = df_box.boxplot()

plt.show()

# %%
# PCA Analysis

# create dataframe for PCA
df_PCA=df2.T

#targets = pd.DataFrame(["a","b"], columns=["target"])
targets = pd.DataFrame(sample_list, columns=["target"])
#df.head()
#targets.head()

#remove NAN and transpose
df_PCA1 = df_PCA.dropna(axis=1, how='any')
print("%d rows with missing values were removed." % (len(df_PCA.columns) - len(df_PCA1.columns)))
#print (df2.head())

# Standardising values
x = df_PCA1.values
x = StandardScaler().fit_transform(x)

pca = PCA(n_components = 2, random_state = 0)
principalComponents = pca.fit_transform(x)
pca_names = [str(i)+str(j) for i,j in zip(['PC']*2,range(1,3))]
principalDf = pd.DataFrame(data = principalComponents, columns = pca_names)

finalDf = pd.concat([principalDf, targets], axis = 1)
finalDf.head()
# Out:
# 791 rows with missing values were removed.
#           PC1         PC2 target
# 0 -376.223225  -28.333598     OE
# 1 -248.639971  369.422273     OE
# 2 -100.699080  110.494153     OE
# 3 -221.905065 -189.855165     OE
# 4 -178.531453 -112.831419     OE

# %%
#plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
fig4, ax4 = plt.subplots(figsize=(7,3))
#colors = ["red","green","blue","yellow","pink","black",
            #"orange","purple","beige","brown","gray",
            #"cyan","magenta"])
plt.scatter(principalComponents[:10, 0], principalComponents[:10, 1],
            edgecolor='none', alpha=0.5, s=200, 
            color='blue', label='OE')
plt.scatter(principalComponents[10:20, 0], principalComponents[10:20, 1],
            edgecolor='none', alpha=0.5, s=200,
            color='yellow', label='OP')
plt.scatter(principalComponents[20:30, 0], principalComponents[20:30, 1],
            edgecolor='none', alpha=0.5, s=200,
            color='green', label='YE')
plt.scatter(principalComponents[30:, 0], principalComponents[30:, 1],
            edgecolor='none', alpha=0.5, s=200,
            color='red', label='YP')

plt.legend(loc='best')
plt.title('2 Component PCA - dermal samples', fontsize = 20)
plt.xlabel('Principal Component 1', fontsize = 15)
plt.ylabel('Principal Component 2', fontsize = 15)
plt.show()

# %%
pca_vars = pca.explained_variance_ratio_
for n,v in zip(pca_names, pca_vars):
    print ("Variance explained by %s : %.4f%%" % (n, v*100))
# Out:
# Variance explained by PC1 : 26.0757%
# Variance explained by PC2 : 8.2164%

# %%
pca2 = PCA().fit(x)
plt.plot(np.cumsum(pca2.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
# create 3D PCA analysis

# Run The PCA
pca3d = PCA(n_components = 3, random_state = 0)
df3d = pca3d.fit_transform(x)
 
# Store results of PCA in a data frame
result=pd.DataFrame(df3d, columns=['PCA%i' % i for i in range(3)])

# %%
# Plot initialisation
fig3 = plt.figure()
ax3 = fig3.add_subplot(111, projection='3d')
ax3.scatter(result['PCA0'].iloc[:10], result['PCA1'].iloc[:10], result['PCA2'].iloc[:10],
            edgecolor='none', alpha=0.5, s=50, 
            color='blue', label='OE')
ax3.scatter(result['PCA0'].iloc[10:20], result['PCA1'].iloc[10:20], result['PCA2'].iloc[10:20],
            edgecolor='none', alpha=0.5, s=50,
            color='yellow', label='OP')
ax3.scatter(result['PCA0'].iloc[20:30], result['PCA1'].iloc[20:30], result['PCA2'].iloc[20:30],
            edgecolor='none', alpha=0.5, s=50,
            color='green', label='YE')
ax3.scatter(result['PCA0'].iloc[30:40], result['PCA1'].iloc[30:40], result['PCA2'].iloc[30:40],
            edgecolor='none', alpha=0.5, s=50,
            color='red', label='YP')
 
# make simple, bare axis lines through space:
xAxisLine = ((min(result['PCA0']), max(result['PCA0'])), (0, 0), (0,0))
ax3.plot(xAxisLine[0], xAxisLine[1], xAxisLine[2], 'r')
yAxisLine = ((0, 0), (min(result['PCA1']), max(result['PCA1'])), (0,0))
ax3.plot(yAxisLine[0], yAxisLine[1], yAxisLine[2], 'r')
zAxisLine = ((0, 0), (0,0), (min(result['PCA2']), max(result['PCA2'])))
ax3.plot(zAxisLine[0], zAxisLine[1], zAxisLine[2], 'r')
 
# label the axes
ax3.set_xlabel("PC1")
ax3.set_ylabel("PC2")
ax3.set_zlabel("PC3")
ax3.set_title("PCA in 3D - dermal")
ax3.legend()
plt.show()
